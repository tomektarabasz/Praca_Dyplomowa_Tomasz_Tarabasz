# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1MjzUke5SDxffqmpruiUzfdBLR6gKbCBM)

# %% [markdown]
# | [1. Spis treści](PD_spis_tresci.ipynb) |
# <br><br>
#
# < [8. Modyfikacje](PD_modyfikacje.ipynb) | [10. Metryki oceny modeli](PD_metryki_oceny_modeli.ipynb) >

# %% [markdown]
# ## [9. Trening zmodyfikowanych modeli]()

# %% [markdown]
# ### Funkcja pomocnicza

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
def print_log(name_of_folder):
  import os
  path_to_gdrive = "./gdrive/My Drive/"
  path_to_r50_t = os.path.join(path_to_gdrive,name_of_folder,"log.txt")
  with open(path_to_r50_t,mode="r") as f:
    print(f.read())
    pass

# %% [markdown]
# ### Opis

# %% [markdown]
# W procesie trenowania rozpatrzono przypadki następujące przypadki:
# - Trening EfficientNet wersja b0 z funkcją strat jako "triplet loss"
# - Trening EfficientNet wersja b7 z funkcją strat jako "triplet loss"
# - Trening EfficientNet wersja b0 z funkcją strat jako "triplet loss + center loss"
# - Trening EfficientNet wersja b0 z funkcją strat jako "triplet loss + center loss" oraz zminiejszonym embeddingiem do 512 wymiarów
# - Trening EfficientNet wersja b0 z funkcją strat jako "triplet loss + center loss" oraz zminiejszonym embeddingiem do 512 wymiarów + zwiększeniem "batch size" do 124 (2x) + zwiększenie kroku uczenia.
# - Trening ResNet50 z funkcją strat jako "triplet loss + center loss" oraz zminiejszonym embeddingiem do 512 wymiarów + zwiększeniem "batch size" do 124 (2x) + zwiększenie kroku uczenia.
# - Trening ResNet50 z funkcją strat jako "triplet loss + center loss" ze zmianą funkcji aktywacji z ReLu na Swish

# %% [markdown]
# ### Trening EfficientNet wersja b0 z funkcją strat jako "triplet loss"

# %%
print_log("E0_T_wyniki_02:02:16")
# Out:
# 2020-09-15 00:00:01,448 reid_baseline INFO: Using 1 GPUS
# 2020-09-15 00:00:01,449 reid_baseline INFO: Namespace(config_file='configs/softmax_triplet.yml', opts=['DATASETS.ROOT_DIR', "'../gdrive/My Drive/Markets1501'", 'MODEL.DEVICE_ID', 'cuda:0', 'DATASETS.NAMES', "('market1501')", 'OUTPUT_DIR', './wyniki/efficient_softmax_triplet', 'MODEL.PRETRAIN_CHOICE', 'efficient', 'MODEL.PRETRAIN_PATH', "'../models/efficientnet-b0.pth'", 'MODEL.NAME', 'efficientnet-b0'])
# 2020-09-15 00:00:01,449 reid_baseline INFO: Loaded configuration file configs/softmax_triplet.yml
# 2020-09-15 00:00:01,449 reid_baseline INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   PRETRAIN_PATH: '/home/haoluo/.torch/models/resnet50-19c8e357.pth'
#   METRIC_LOSS_TYPE: 'triplet'
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'no'
#
#
#
#
# INPUT:
#   SIZE_TRAIN: [256, 128]
#   SIZE_TEST: [256, 128]
#   PROB: 0.5 # random horizontal flip
#   RE_PROB: 0.5 # random erasing
#   PADDING: 10
#
# DATASETS:
# ...

# %% [markdown]
# ### Trening EfficientNet wersja b7 z funkcją strat jako "triplet loss"

# %%
print_log("E7_T_wyniki_11:57:37")
# Out:
# 2020-09-15 07:51:14,750 reid_baseline INFO: Using 1 GPUS
# 2020-09-15 07:51:14,751 reid_baseline INFO: Namespace(config_file='configs/softmax_triplet.yml', opts=['DATASETS.ROOT_DIR', "'../gdrive/My Drive/Markets1501'", 'MODEL.DEVICE_ID', 'cuda:0', 'DATASETS.NAMES', "('market1501')", 'OUTPUT_DIR', './wyniki/efficient_softmax_triplet_b7', 'MODEL.PRETRAIN_CHOICE', 'efficient', 'MODEL.PRETRAIN_PATH', "'../models/efficientnet-b7.pth'", 'MODEL.NAME', 'efficientnet-b7'])
# 2020-09-15 07:51:14,751 reid_baseline INFO: Loaded configuration file configs/softmax_triplet.yml
# 2020-09-15 07:51:14,751 reid_baseline INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   PRETRAIN_PATH: '/home/haoluo/.torch/models/resnet50-19c8e357.pth'
#   METRIC_LOSS_TYPE: 'triplet'
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'no'
#
#
#
#
# INPUT:
#   SIZE_TRAIN: [256, 128]
#   SIZE_TEST: [256, 128]
#   PROB: 0.5 # random horizontal flip
#   RE_PROB: 0.5 # random erasing
#   PADDING: 10
#
# DATASETS:
# ...

# %% [markdown]
# ### Trening EfficientNet wersja b0 z funkcją strat jako "triplet loss + center loss"

# %%
print_log("E0_TC_wyniki_19:48:47")
# Out:
# 2020-09-15 18:12:27,044 reid_baseline INFO: Using 1 GPUS
# 2020-09-15 18:12:27,044 reid_baseline INFO: Namespace(config_file='configs/softmax_triplet_with_center.yml', opts=['DATASETS.ROOT_DIR', "'../gdrive/My Drive/Markets1501'", 'MODEL.DEVICE_ID', 'cuda:0', 'DATASETS.NAMES', "('market1501')", 'OUTPUT_DIR', './wyniki/efficient_center_loss', 'MODEL.PRETRAIN_CHOICE', 'efficient', 'MODEL.PRETRAIN_PATH', "'../models/efficientnet-b0.pth'", 'MODEL.NAME', 'efficientnet-b0', 'MODEL.EMBEDING_SIZE', '512'])
# 2020-09-15 18:12:27,044 reid_baseline INFO: Loaded configuration file configs/softmax_triplet_with_center.yml
# 2020-09-15 18:12:27,044 reid_baseline INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   PRETRAIN_PATH: '/home/haoluo/.torch/models/resnet50-19c8e357.pth'
#   METRIC_LOSS_TYPE: 'triplet_center'
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'yes'
#
#
#
#
# INPUT:
#   SIZE_TRAIN: [256, 128]
#   SIZE_TEST: [256, 128]
#   PROB: 0.5 # random horizontal flip
# ...

# %% [markdown]
# ### Trening EfficientNet wersja b0 z funkcją strat jako "triplet loss + center loss" oraz zminiejszonym embeddingiem do 512 wymiarów

# %%
print_log("E0_TC_M_wyniki_05:00:14")
# Out:
# 2020-09-16 02:19:31,164 reid_baseline INFO: Using 1 GPUS
# 2020-09-16 02:19:31,164 reid_baseline INFO: Namespace(config_file='configs/softmax_triplet_with_center.yml', opts=['DATASETS.ROOT_DIR', "'../gdrive/My Drive/Markets1501'", 'MODEL.DEVICE_ID', 'cuda:0', 'DATASETS.NAMES', "('market1501')", 'OUTPUT_DIR', './wyniki/efficient_center_loss_M', 'MODEL.PRETRAIN_CHOICE', 'efficient', 'MODEL.PRETRAIN_PATH', "'../models/efficientnet-b0.pth'", 'MODEL.NAME', 'efficientnet-b0', 'MODEL.EMBEDING_SIZE', '512'])
# 2020-09-16 02:19:31,164 reid_baseline INFO: Loaded configuration file configs/softmax_triplet_with_center.yml
# 2020-09-16 02:19:31,164 reid_baseline INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   PRETRAIN_PATH: '/home/haoluo/.torch/models/resnet50-19c8e357.pth'
#   METRIC_LOSS_TYPE: 'triplet_center'
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'yes'
#
#
#
#
# INPUT:
#   SIZE_TRAIN: [256, 128]
#   SIZE_TEST: [256, 128]
#   PROB: 0.5 # random horizontal flip
# ...

# %% [markdown]
# ### Trening EfficientNet wersja b0 z funkcją strat jako "triplet loss + center loss" oraz zminiejszonym embeddingiem do 512 wymiarów + zwiększeniem "batch size" do 124 (2x) + zwiększenie kroku uczenia.

# %%
print_log("E0_TC_M3_wyniki_16:01:10")
# Out:
# 2020-09-16 13:40:44,422 reid_baseline INFO: Using 1 GPUS
# 2020-09-16 13:40:44,422 reid_baseline INFO: Namespace(config_file='configs/softmax_triplet_with_center.yml', opts=['DATASETS.ROOT_DIR', "'../gdrive/My Drive/Markets1501'", 'MODEL.DEVICE_ID', 'cuda:0', 'DATASETS.NAMES', "('market1501')", 'OUTPUT_DIR', './wyniki/efficient_center_loss_M', 'MODEL.PRETRAIN_CHOICE', 'efficient', 'MODEL.PRETRAIN_PATH', "'../models/efficientnet-b0.pth'", 'MODEL.NAME', 'efficientnet-b0', 'MODEL.EMBEDING_SIZE', '512'])
# 2020-09-16 13:40:44,422 reid_baseline INFO: Loaded configuration file configs/softmax_triplet_with_center.yml
# 2020-09-16 13:40:44,422 reid_baseline INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   PRETRAIN_PATH: '/home/haoluo/.torch/models/resnet50-19c8e357.pth'
#   METRIC_LOSS_TYPE: 'triplet_center'
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'yes'
#
#
#
#
# INPUT:
#   SIZE_TRAIN: [256, 128]
#   SIZE_TEST: [256, 128]
#   PROB: 0.5 # random horizontal flip
# ...

# %% [markdown]
# ### Trening ResNet50 z funkcją strat jako "triplet loss + center loss" oraz zminiejszonym embeddingiem do 512 wymiarów + zwiększeniem "batch size" do 124 (2x) + zwiększenie kroku uczenia.

# %%
print_log("R50-TC-M3-wyniki17:29:13")
# Out:
# 2020-09-16 16:03:00,583 reid_baseline INFO: Using 1 GPUS
# 2020-09-16 16:03:00,583 reid_baseline INFO: Namespace(config_file='configs/softmax_triplet_with_center.yml', opts=['DATASETS.ROOT_DIR', "'../gdrive/My Drive/Markets1501'", 'MODEL.DEVICE_ID', 'cuda:0', 'DATASETS.NAMES', "('market1501')", 'OUTPUT_DIR', './wyniki/resnet50_center_loss', 'MODEL.PRETRAIN_PATH', "'../models/resnet50-19c8e357.pth'"])
# 2020-09-16 16:03:00,583 reid_baseline INFO: Loaded configuration file configs/softmax_triplet_with_center.yml
# 2020-09-16 16:03:00,584 reid_baseline INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   PRETRAIN_PATH: '/home/haoluo/.torch/models/resnet50-19c8e357.pth'
#   METRIC_LOSS_TYPE: 'triplet_center'
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'yes'
#
#
#
#
# INPUT:
#   SIZE_TRAIN: [256, 128]
#   SIZE_TEST: [256, 128]
#   PROB: 0.5 # random horizontal flip
#   RE_PROB: 0.5 # random erasing
#   PADDING: 10
#
# DATASETS:
#   NAMES: ('market1501')
#
# DATALOADER:
# ...

# %% [markdown]
# ### Trening ResNet50 z funkcją strat jako "triplet loss + center loss" ze zmianą funkcji aktywacji z ReLu na Swish

# %%
print_log("R50_Swish_TC_wyniki_21:17:28")
# Out:
# 2020-09-15 19:48:51,338 reid_baseline INFO: Using 1 GPUS
# 2020-09-15 19:48:51,339 reid_baseline INFO: Namespace(config_file='configs/softmax_triplet_with_center.yml', opts=['DATASETS.ROOT_DIR', "'../gdrive/My Drive/Markets1501'", 'MODEL.DEVICE_ID', 'cuda:0', 'DATASETS.NAMES', "('market1501')", 'OUTPUT_DIR', './wyniki/resnet50_swish_center', 'MODEL.PRETRAIN_PATH', "'../models/resnet50-19c8e357.pth'", 'MODEL.NAME', 'resnet50_swish', 'MODEL.EMBEDING_SIZE', '512'])
# 2020-09-15 19:48:51,339 reid_baseline INFO: Loaded configuration file configs/softmax_triplet_with_center.yml
# 2020-09-15 19:48:51,339 reid_baseline INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   PRETRAIN_PATH: '/home/haoluo/.torch/models/resnet50-19c8e357.pth'
#   METRIC_LOSS_TYPE: 'triplet_center'
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'yes'
#
#
#
#
# INPUT:
#   SIZE_TRAIN: [256, 128]
#   SIZE_TEST: [256, 128]
#   PROB: 0.5 # random horizontal flip
#   RE_PROB: 0.5 # random erasing
#   PADDING: 10
#
# ...

# %% [markdown]
# ## Nawigacja

# %% [markdown]
# | [1. Spis treści](PD_spis_tresci.ipynb) |
# <br><br>
#
# < [8. Modyfikacje](PD_modyfikacje.ipynb) | [10. Metryki oceny modeli](PD_metryki_oceny_modeli.ipynb) >
